# %%
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir('C:/Users/basleal/Desktop/tutorial/kaim-week-7')
print(os.getcwd())
# Out:
# C:\Users\basleal\Desktop\tutorial\kaim-week-7

# %%
path = 'C:/Users/basleal/Desktop/tutorial/kaim-week-7/data/telegram_data.csv'
data = pd.read_csv(path)
data
# Out:
#                                           Channel Title  \
# 0                                      Doctors Ethiopia
# 1                                      Doctors Ethiopia
# 2                                      Doctors Ethiopia
# 3                                      Doctors Ethiopia
# 4                                      Doctors Ethiopia
# ...                                                 ...
# 6424  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...
# 6425  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...
# 6426  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...
# 6427  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...
# 6428  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...
#
#             Channel Username   ID  \
# 0     https://t.me/DoctorsET  864
# 1     https://t.me/DoctorsET  863
# 2     https://t.me/DoctorsET  862
# 3     https://t.me/DoctorsET  861
# 4     https://t.me/DoctorsET  860
# ...                      ...  ...
# 6424      https://t.me/EAHCI    8
# ...

# %%
data.isnull().sum()
# Out:
# Channel Title          0
# Channel Username       0
# ID                     0
# Message             1243
# Date                   0
# Media Path          6429
# dtype: int64

# %%
from scripts.data_cleaning import data_cleaner
cleaned_data=data_cleaner(data)
cleaned_data
# Out:
#                                           Channel Title  \
# 0                                      doctors ethiopia
# 1                                      doctors ethiopia
# 2                                      doctors ethiopia
# 3                                      doctors ethiopia
# 4                                      doctors ethiopia
# ...                                                 ...
# 6424  ethio-american medical trainings( cpd ) & heal...
# 6425  ethio-american medical trainings( cpd ) & heal...
# 6426  ethio-american medical trainings( cpd ) & heal...
# 6427  ethio-american medical trainings( cpd ) & heal...
# 6428  ethio-american medical trainings( cpd ) & heal...
#
#             Channel Username   ID  \
# 0     https://t.me/DoctorsET  864
# 1     https://t.me/DoctorsET  863
# 2     https://t.me/DoctorsET  862
# 3     https://t.me/DoctorsET  861
# 4     https://t.me/DoctorsET  860
# ...                      ...  ...
# 6424      https://t.me/EAHCI    8
# ...

# %%
from scripts.data_cleaning import data_validation
validated_data=data_validation(cleaned_data)
validated_data
# Out:
#  Data validation complete
# (Empty DataFrame
#  Columns: [Channel Title, Channel Username, ID, Message, Date, Media Path]
#  Index: [],
#  None)

# %%
cleaned_data
# Out:
#                                           Channel Title  \
# 0                                      doctors ethiopia
# 1                                      doctors ethiopia
# 2                                      doctors ethiopia
# 3                                      doctors ethiopia
# 4                                      doctors ethiopia
# ...                                                 ...
# 6424  ethio-american medical trainings( cpd ) & heal...
# 6425  ethio-american medical trainings( cpd ) & heal...
# 6426  ethio-american medical trainings( cpd ) & heal...
# 6427  ethio-american medical trainings( cpd ) & heal...
# 6428  ethio-american medical trainings( cpd ) & heal...
#
#             Channel Username   ID  \
# 0     https://t.me/DoctorsET  864
# 1     https://t.me/DoctorsET  863
# 2     https://t.me/DoctorsET  862
# 3     https://t.me/DoctorsET  861
# 4     https://t.me/DoctorsET  860
# ...                      ...  ...
# 6424      https://t.me/EAHCI    8
# ...

# %%
cleaned_data.to_csv('cleaned_data.csv')
